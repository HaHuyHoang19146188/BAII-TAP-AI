# %% [markdown]
# <a href="https://colab.research.google.com/github/HaHuyHoang19146188/BAII-TAP-AI/blob/main/MONEY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Khai báo và sử dụng các thư viện sau
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop,Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Chuyển đến file Google Drive chứa bộ ảnh đã tạo
# %cd"/content/drive/MyDrive/MONEY"
# Out:
# /content/drive/MyDrive/MONEY

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
# Tạo bộ dữ liệu training set
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/MONEY/TRAINGING',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 220 images belonging to 11 classes.

# %%
# Tạo bộ dữ liệu validation set
validation=train_datagen.flow_from_directory('/content/drive/MyDrive/MONEY/VALIDATION',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 44 images belonging to 11 classes.

# %%
#các nhãn có trong bộ dữ liệu train
training_set.class_indices
# Out:
# {'1000': 0,
#  '10000': 1,
#  '100000': 2,
#  '200': 3,
#  '2000': 4,
#  '20000': 5,
#  '200000': 6,
#  '500': 7,
#  '5000': 8,
#  '50000': 9,
#  '500000': 10}

# %%
#các nhãn có trong bộ dữ liệu validation
validation.class_indices
# Out:
# {'1000': 0,
#  '10000': 1,
#  '100000': 2,
#  '200': 3,
#  '2000': 4,
#  '20000': 5,
#  '200000': 6,
#  '500': 7,
#  '5000': 8,
#  '50000': 9,
#  '500000': 10}

# %%
model=Sequential()
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(11,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 128)               5308544
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 5,596,971
# Trainable params: 5,596,971
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])
# Gán biến lại để vẽ đồ thị, với 500 lần học (epochs), mỗi lần học thì chỉ học␣128 dữ liệu (batch_size), khi sai số không thay đổi trong 20 lần học thì sẽ␣ dừng học 
history=model.fit(training_set,epochs=500,batch_size=128,verbose=1, validation_data=validation, callbacks=[EarlyStopping(monitor='val_loss', patience=20)]) # verbose=1 để hiển thị quá trinh học
# Out:
# Epoch 1/500
# 7/7 [==============================] - 30s 4s/step - loss: 0.1962 - accuracy: 0.9591 - val_loss: 0.3139 - val_accuracy: 0.9773
# Epoch 2/500
# 7/7 [==============================] - 25s 3s/step - loss: 0.3845 - accuracy: 0.9227 - val_loss: 0.1120 - val_accuracy: 0.9545
# Epoch 3/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.1506 - accuracy: 0.9455 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 4/500
# 7/7 [==============================] - 25s 3s/step - loss: 0.1362 - accuracy: 0.9591 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 5/500
# 7/7 [==============================] - 24s 4s/step - loss: 0.1473 - accuracy: 0.9545 - val_loss: 0.0271 - val_accuracy: 0.9773
# Epoch 6/500
# 7/7 [==============================] - 24s 4s/step - loss: 0.0434 - accuracy: 0.9818 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 7/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0916 - accuracy: 0.9636 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 8/500
# 7/7 [==============================] - 25s 3s/step - loss: 0.0674 - accuracy: 0.9773 - val_loss: 1.7852e-04 - val_accuracy: 1.0000
# Epoch 9/500
# 7/7 [==============================] - 25s 4s/step - loss: 0.0262 - accuracy: 0.9864 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 10/500
# 7/7 [==============================] - 25s 3s/step - loss: 0.0540 - accuracy: 0.9727 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 11/500
# 7/7 [==============================] - 25s 3s/step - loss: 0.0464 - accuracy: 0.9818 - val_loss: 6.8876e-04 - val_accuracy: 1.0000
# Epoch 12/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0616 - accuracy: 0.9727 - val_loss: 2.3142e-04 - val_accuracy: 1.0000
# Epoch 13/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0290 - accuracy: 0.9864 - val_loss: 4.6894e-04 - val_accuracy: 1.0000
# Epoch 14/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0418 - accuracy: 0.9864 - val_loss: 8.5695e-05 - val_accuracy: 1.0000
# Epoch 15/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0362 - accuracy: 0.9909 - val_loss: 2.7660e-05 - val_accuracy: 1.0000
# Epoch 16/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0225 - accuracy: 0.9955 - val_loss: 0.0381 - val_accuracy: 0.9773
# Epoch 17/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.2959 - accuracy: 0.9227 - val_loss: 0.1921 - val_accuracy: 0.9318
# Epoch 18/500
# 7/7 [==============================] - 25s 4s/step - loss: 0.3448 - accuracy: 0.9136 - val_loss: 0.0433 - val_accuracy: 0.9773
# Epoch 19/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.2095 - accuracy: 0.9364 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 20/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.1700 - accuracy: 0.9500 - val_loss: 0.0497 - val_accuracy: 0.9773
# Epoch 21/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.1085 - accuracy: 0.9636 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 22/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.1571 - accuracy: 0.9545 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 23/500
# 7/7 [==============================] - 24s 4s/step - loss: 0.1331 - accuracy: 0.9591 - val_loss: 0.0254 - val_accuracy: 1.0000
# Epoch 24/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0570 - accuracy: 0.9909 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 25/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0435 - accuracy: 0.9818 - val_loss: 0.0281 - val_accuracy: 0.9773
# Epoch 26/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0589 - accuracy: 0.9818 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 27/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0415 - accuracy: 0.9909 - val_loss: 3.2007e-04 - val_accuracy: 1.0000
# Epoch 28/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 4.1417e-04 - val_accuracy: 1.0000
# Epoch 29/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0349 - accuracy: 0.9864 - val_loss: 1.1829e-04 - val_accuracy: 1.0000
# Epoch 30/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 5.2715e-04 - val_accuracy: 1.0000
# Epoch 31/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0251 - accuracy: 0.9955 - val_loss: 2.1294e-04 - val_accuracy: 1.0000
# Epoch 32/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0100 - accuracy: 0.9955 - val_loss: 1.7321e-04 - val_accuracy: 1.0000
# Epoch 33/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0411 - accuracy: 0.9864 - val_loss: 1.8971e-04 - val_accuracy: 1.0000
# Epoch 34/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 35/500
# 7/7 [==============================] - 24s 3s/step - loss: 0.0172 - accuracy: 0.9909 - val_loss: 4.1491e-04 - val_accuracy: 1.0000

# %%
# Đánh giá độ chính xác của mô hình sau khi đã train 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.0031654085032641888
# Train Accuracy 1.0

# %%
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
img=load_img('/content/drive/MyDrive/MONEY/TEST/465556d46097a0c9f986.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,150,150,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='1000'
elif round(result[0][1])==1:
  prediction='10000'
elif round(result[0][2])==1:
  prediction='100000'
elif round(result[0][3])==1:
  prediction='200'  
elif round(result[0][4])==1:
  prediction='2000'
elif round(result[0][5])==1:
  prediction='20000'
elif round(result[0][6])==1:
  prediction='200000'
elif round(result[0][7])==1:
  prediction='500'
elif round(result[0][8])==1:
  prediction='5000'
elif round(result[0][9])==1:
  prediction='50000'  
elif round(result[0][10])==1:
  prediction='500000'  
print(prediction)
# Out:
# 5000

# %%
# Lưu lại
model.save("Food.h5")
# Tải mô hình 
model_CNN=load_model('Food.h5')

# %%
img=load_img('/content/drive/MyDrive/MONEY/TEST/vip13-20k-seri-jd-07777777.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,150,150,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='1000'
elif round(result[0][1])==1:
  prediction='10000'
elif round(result[0][2])==1:
  prediction='100000'
elif round(result[0][3])==1:
  prediction='200'  
elif round(result[0][4])==1:
  prediction='2000'
elif round(result[0][5])==1:
  prediction='20000'
elif round(result[0][6])==1:
  prediction='200000'
elif round(result[0][7])==1:
  prediction='500'
elif round(result[0][8])==1:
  prediction='5000'
elif round(result[0][9])==1:
  prediction='50000'  
elif round(result[0][10])==1:
  prediction='500000'  
print(prediction)
# Out:
# 20000
